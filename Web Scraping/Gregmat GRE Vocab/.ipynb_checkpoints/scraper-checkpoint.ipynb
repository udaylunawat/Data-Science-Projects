# %%
import pandas as pd
import requests
import lxml
from lxml import html
import time
import json
from tqdm.notebook import tqdm

# %%
from utilities import *

# %%
words = pd.read_excel('Words from GRE Vocabulary Assessment Videos.xlsx', header=None)
words = words.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %%
max_groups = 28
max_set_words = 30

# %%
# # Create new
# ankified = pd.DataFrame(columns=['words','definition','synonyms','mnemonics','image_url'])

ankified = pd.read_csv('anki_mnemonics.csv')

# %%
ankified
# Out:
#           words                                         definition  \
# 0        abound  (verb) be abundant or plentiful; exist in larg...
# 1     amorphous    (adj) having no definite form or distinct shape
# 2       austere                              (adj) severely simple
# 3         belie                    (verb) be in contradiction with
# 4    capricious                                   (adj) changeable
# ..          ...                                                ...
# 835   sophistry  (noun) a deliberately invalid argument display...
# 836    penchant                             (noun) a strong liking
# 837      gauche                        (adj) lacking social polish
# 838   deprecate      (verb) express strong disapproval of; deplore
# 839     affront  (noun) a deliberately offensive act or somethi...
#
#                                               synonyms  \
# 0                                        bristle,burst
# 1    formless,shapeless,unstructured,uncrystallised...
# 2    severe,stark,stern,stern,ascetic,ascetical,spa...
# 3                       contradict,negate,misrepresent
# 4                         freakish,impulsive,whimsical
# ..                                                 ...
# 835                             sophism,sophistication
# 836                      predilection,preference,taste
# 837                               graceless,unpolished
# 838                                depreciate,vilipend
# 839                                 insult,diss,insult
#
#                                              mnemonics  \
# 0    Mnemonic 1: Bounded means limited. Abound mean...
# 1    Mnemonic 1: In Greek 'morphe' means shape/form...
# 2    Mnemonic 1: AUS-australia TERE-tear(sorrow). l...
# 3    Mnemonic 1: belie ~ lie means something false....
# 4    Mnemonic 1: ca(CAR) + PRIC(PRICE)...PRICE OF c...
# ..                                                 ...
# 835  Mnemonic 1: so physics is = chemistry.. its a ...
# 836  Mnemonic 1: p+enchant- something that enchants...
# 837  Mnemonic 1: Ghochu\nMnemonic 2: gauchy sounds ...
# 838  Mnemonic 1: You can think of it as the opposit...
# 839  Mnemonic 1: Affront=A(Aao)+front means if u co...
#
#                                              image_url     Set
# 0                                                  NaN   Set 1
# 1                                                  NaN   Set 1
# 2                                                  NaN   Set 1
# 3                                                  NaN   Set 1
# 4                                                  NaN   Set 1
# ..                                                 ...     ...
# 835                                                NaN  Set 28
# 836  <img src="https://dailyvocab.com/wp-content/up...  Set 28
# 837                                                NaN  Set 28
# 838                                                NaN  Set 28
# 839  <img src="https://dailyvocab.com/wp-content/up...  Set 28
#
# [840 rows x 6 columns]

# %%
# ankified['mnemonics'][2].strip('[]')
# ankified['mnemonics'] = ankified['mnemonics'].apply(lambda x: None if x == '[]' else x)
# ankified['mnemonics'] = ankified['mnemonics'].apply(lambda x: x.strip('[]').split(',') if x != None else None) # String to list
# ankified['mnemonics'] = ankified['mnemonics'].apply(lambda x: mnemo_list_to_string(x) if x != 'NaN' else x) # list to mnemonics

# %%
total_sets = 28
for set_no in range(1, total_sets+1):
    word_list = list(get_my_set(words, set_no))
    ankified = add_set(ankified, word_list, set_no, sleep = False)
# Out:
# Added Word acquiesce.
# Added Word adroit.
# Added Word amend.
# Added Word animus.
# Added Word apologist.
# Added Word astringent.
# Added Word collaborate.
# Added Word competent.
# Added Word correlate.
# Added Word deride.
# Added Word dictate.
# Added Word discreet.
# Added Word divorced.
# Added Word elitist.
# Added Word exacting.
# flummoxed not found at mnemonicdictionary.com!
# Added Word flummoxed.
# Added Word fruitful.
# Added Word inborn.
# Added Word polymath.
# Added Word reticent.
# Added Word stringent.
# Added Word subservient.
# Added Word surreptitious.
# Added Word tantalizing.
# Added Word tantamount.
# Added Word torpor.
# Added Word trenchant.
# Added Word umbrage.
# Added Word versatile.
# Added Word wayward.
# Added Word alienate.
# Added Word apathy.
# Added Word apropos.
# Added Word apt.
# Added Word cloak.
# Added Word consensus.
# Added Word distort.
# Added Word divergent.
# Added Word elated.
# Added Word enchant.
# Added Word entrenched.
# Added Word exotic.
# Added Word exploitative.
# Added Word foreseeable.
# Added Word forsake.
# Added Word gratify.
# Added Word heed.
# Added Word judicious.
# Added Word lucid.
# Added Word pertinent.
# Added Word propriety.
# Added Word scintillating.
# Added Word sensational.
# Added Word sophisticated.
# Added Word strife.
# Added Word understated.
# Added Word unscrupulous.
# Added Word veracity.
# Added Word virulent.
# Added Word volatile.
# Added Word antedate.
# Added Word banish.
# Added Word bridle.
# Added Word comply.
# Added Word crestfallen.
# Added Word curtail.
# Added Word elucidate.
# Added Word evade.
# Added Word feckless.
# Added Word fester.
# Added Word iconoclastic.
# Added Word immure.
# Added Word improvise.
# Added Word inhibit.
# Added Word inscrutable.
# Added Word lionize.
# Added Word monotonous.
# Added Word peculiar.
# Added Word premeditate.
# Added Word profligate.
# Added Word reconcile.
# Added Word refine.
# Added Word relinquish.
# Added Word ruminate.
# Added Word skittish.
# Added Word superfluous.
# Added Word synoptic.
# Added Word thorough.
# Added Word visionary.
# Added Word vociferous.
# Added Word acclaim.
# Added Word ascertain.
# Added Word assertive.
# Added Word bogus.
# Added Word cataclysmic.
# Added Word circumscribe.
# Added Word complementary.
# Added Word contentious.
# Added Word disingenuous.
# Added Word divulge.
# Added Word dogmatic.
# Added Word fallacious.
# Added Word foolhardy.
# Added Word hinder.
# Added Word impair.
# Added Word impugn.
# Added Word incessant.
# Added Word inclined.
# Added Word inveterate.
# Added Word miserly.
# Added Word patent.
# Added Word petulant.
# Added Word pithy.
# Added Word pliant.
# Added Word sanctimonious.
# Added Word sound.
# Added Word tarnish.
# Added Word tepid.
# Added Word upbraid.
# Added Word vexation.
# Added Word abet.
# Added Word accessible.
# Added Word acquisitive.
# Added Word amalgamate.
# Added Word attenuate.
# Added Word augment.
# Added Word aversion.
# Added Word blithe.
# Added Word contempt.
# Added Word dawdle.
# Added Word deflect.
# Added Word discount.
# Added Word dissident.
# Added Word efficacious.
# Added Word equitable.
# Added Word erratic.
# Added Word industrious.
# Added Word inform.
# Added Word irksome.
# Added Word manacle.
# Added Word modest.
# Added Word noxious.
# Added Word pernicious.
# Added Word predicament.
# Added Word proficient.
# Added Word prolix.
# Added Word scorn.
# Added Word subordinate.
# Added Word unseemly.
# Added Word veritable.
# Added Word acolyte.
# Added Word anoint.
# Added Word base.
# Added Word coercion.
# Added Word coin.
# Added Word cunning.
# Added Word discomfit.
# Added Word dissent.
# Added Word distill.
# Added Word dubious.
# Added Word ebullient.
# Added Word facetious.
# Added Word fallible.
# Added Word florid.
# Added Word gawky.
# Added Word inveigle.
# Added Word jettison.
# Added Word mendacity.
# Added Word munificent.
# Added Word naive.
# Added Word noble.
# Added Word parochial.
# Added Word pedestrian.
# Added Word prevaricate.
# Added Word prime.
# Added Word radical.
# Added Word recrudescent.
# Added Word temporal.
# Added Word transitory.
# Added Word viable.
# Added Word abreast.
# Added Word confound.
# Added Word digression.
# Added Word discrepancy.
# Added Word duplicitous.
# Added Word expedient.
# Added Word fabricate.
# Added Word glum.
# Added Word harbinger.
# Added Word intrinsic.
# Added Word largesse.
# Added Word libertine.
# Added Word malfeasance.
# Added Word manifest.
# Added Word minute.
# Added Word modish.
# Added Word nascent.
# Added Word perennial.
# Added Word pious.
# Added Word providential.
# Added Word prowess.
# Added Word schism.
# Added Word slander.
# Added Word stalwart.
# Added Word supplicate.
# Added Word terse.
# Added Word tirade.
# Added Word universal.
# Added Word vanquish.
# Added Word woeful.
# Added Word abject.
# Added Word amicable.
# Added Word animosity.
# Added Word aver.
# Added Word barrage.
# Added Word cathartic.
# Added Word decipher.
# Added Word delusion.
# Added Word dispense.
# Added Word eloquent.
# Added Word enthrall.
# Added Word eradicate.
# Added Word fledgling.
# Added Word fortitude.
# Added Word fortuitous.
# Added Word goad.
# Added Word imminent.
# Added Word incontrovertible.
# Added Word itinerant.
# Added Word magnanimous.
# Added Word meritorious.
# Added Word mutiny.
# Added Word paradoxical.
# Added Word perseverance.
# Added Word render.
# Added Word repertoire.
# Added Word resilient.
# Added Word resolute.
# Added Word supple.
# Added Word valor.
# Added Word cumbersome.
# Added Word unprecedented.
# Added Word stinting.
# Added Word extrapolate.
# Added Word liability.
# Added Word euphoric.
# Added Word elementary.
# Added Word heterodox.
# Added Word fervent.
# Added Word gaffe.
# Added Word temper.
# Added Word painstaking.
# Added Word economy.
# Added Word qualm.
# Added Word exonerate.
# Added Word implicit.
# Added Word phlegmatic.
# Added Word propensity.
# Added Word foment.
# Added Word embellish.
# Added Word inviolate.
# Added Word renege.
# Added Word arresting.
# Added Word obstinate.
# Added Word vivacious.
# Added Word histrionic.
# Added Word prodigious.
# Added Word tentative.
# Added Word falter.
# Added Word chastise.
# Added Word intermittent.
# Added Word profound.
# Added Word propagate.
# Added Word allusive.
# Added Word glib.
# Added Word curb.
# Added Word lull.
# Added Word mettlesome.
# Added Word astute.
# Added Word fawn.
# Added Word precipitous.
# Added Word repercussion.
# Added Word regress.
# Added Word refute.
# Added Word replenish.
# Added Word evoke.
# Added Word ire.
# Added Word languid.
# Added Word mollify.
# Added Word pretentious.
# Added Word duress.
# Added Word vigilant.
# Added Word headstrong.
# Added Word convalescent.
# Added Word nonplussed.
# Added Word fret.
# Added Word decry.
# Added Word recourse.
# Added Word commence.
# Added Word neutralize.
# Added Word exorcise.
# Added Word finicky.
# Added Word assail.
# Added Word contravene.
# Added Word reiterate.
# Added Word poignant.
# Added Word inundate.
# Added Word oblivious.
# Added Word ironclad.
# Added Word plaintive.
# Added Word surmount.
# Added Word escalate.
# Added Word denounce.
# Added Word foil.
# Added Word deviate.
# Added Word buoyant.
# Added Word benevolent.
# intertwined not found at mnemonicdictionary.com!
# Added Word intertwined.
# Added Word berate.
# Added Word quiescent.
# Added Word mercurial.
# Added Word despotic.
# Added Word perpetrate.
# Added Word subsume.
# Added Word subside.
# Added Word condone.
# Added Word tangential.
# Added Word jeopardize.
# Added Word disinterested.
# Added Word buttress.
# Added Word bereft.
# Added Word frailty.
# Added Word disentangle.
# Added Word pomposity.
# Added Word delineate.
# Added Word conclusive.
# Added Word vitality.
# Added Word steadfast.
# Added Word archetype.
# Added Word relent.
# Added Word grievance.
# Added Word harangue.
# Added Word auspicious.
# Added Word yield.
# Added Word appropriate.
# Added Word rhetoric.
# Added Word conspire.
# Added Word whimsical.
# Added Word proxy.
# Added Word sparse.
# Added Word adverse.
# Added Word exhort.
# Added Word poise.
# Added Word adept.
# Added Word tedious.
# Added Word rigor.
# Added Word articulate.
# Added Word suspect.
# Added Word ploy.
# Added Word captious.
# Added Word lugubrious.
# Added Word transcend.
# Added Word flustered.
# Added Word incidental.
# Added Word axiomatic.
# Added Word macabre.
# Added Word gullible.
# Added Word ingrained.
# Added Word tacit.
# Added Word exorbitant.
# Added Word serene.
# Added Word treatise.
# Added Word corporeal.
# Added Word figurative.
# Added Word morose.
# Added Word fickle.
# Added Word ramification.
# Added Word eclectic.
# Added Word apprehension.
# Added Word idiosyncratic.
# Added Word insolent.
# Added Word ardent.
# Added Word doctrinaire.
# Added Word officious.
# Added Word cease.
# Added Word lavish.
# Added Word conducive.
# Added Word equanimity.
# Added Word supplant.
# Added Word lampoon.
# Added Word bombastic.
# Added Word lambaste.
# Added Word undercut.
# Added Word euphemism.
# Added Word turpitude.
# Added Word peccadillo.
# Added Word antagonize.
# Added Word barren.
# Added Word philistine.
# Added Word relegate.
# Added Word dirge.
# Added Word imperturbable.
# Added Word excoriate.
# Added Word curmudgeon.
# Added Word swindle.
# Added Word wheedle.
# Added Word sentimental.
# Added Word miscreant.
# Added Word implacable.
# Added Word haughty.
# Added Word estimable.
# Added Word tangible.
# Added Word chary.
# Added Word repugnant.
# Added Word xenophobic.
# Added Word squander.
# Added Word cajole.
# Added Word unalloyed.
# Added Word heady.
# Added Word exigent.
# Added Word hysterical.
# Added Word endemic.
# Added Word disdain.
# Added Word quash.
# Added Word august.
# Added Word quibble.
# Added Word recant.
# Added Word inchoate.
# Added Word abeyance.
# Added Word redoubtable.
# Added Word coy.
# Added Word disperse.
# Added Word shrill.
# Added Word impudent.
# Added Word burnish.
# Added Word wily.
# Added Word quandary.
# Added Word enmity.
# Added Word substantiate.
# Added Word agitate.
# Added Word abstract.
# Added Word retiring.
# Added Word quarantine.
# Added Word distend.
# Added Word ravage.
# Added Word sophistry.
# Added Word penchant.
# Added Word gauche.
# Added Word deprecate.
# Added Word affront.

# %%
ankified
# Out:
#           words                                         definition  \
# 0        abound  (verb) be abundant or plentiful; exist in larg...
# 1     amorphous    (adj) having no definite form or distinct shape
# 2       austere                              (adj) severely simple
# 3         belie                    (verb) be in contradiction with
# 4    capricious                                   (adj) changeable
# ..          ...                                                ...
# 835   sophistry  (noun) a deliberately invalid argument display...
# 836    penchant                             (noun) a strong liking
# 837      gauche                        (adj) lacking social polish
# 838   deprecate      (verb) express strong disapproval of; deplore
# 839     affront  (noun) a deliberately offensive act or somethi...
#
#                                               synonyms  \
# 0                                        bristle,burst
# 1    formless,shapeless,unstructured,uncrystallised...
# 2    severe,stark,stern,stern,ascetic,ascetical,spa...
# 3                       contradict,negate,misrepresent
# 4                         freakish,impulsive,whimsical
# ..                                                 ...
# 835                             sophism,sophistication
# 836                      predilection,preference,taste
# 837                               graceless,unpolished
# 838                                depreciate,vilipend
# 839                                 insult,diss,insult
#
#                                              mnemonics  \
# 0    Mnemonic 1: Bounded means limited. Abound mean...
# 1    Mnemonic 1: In Greek 'morphe' means shape/form...
# 2    Mnemonic 1: AUS-australia TERE-tear(sorrow). l...
# 3    Mnemonic 1: belie ~ lie means something false....
# 4    Mnemonic 1: ca(CAR) + PRIC(PRICE)...PRICE OF c...
# ..                                                 ...
# 835  Mnemonic 1: so physics is = chemistry.. its a ...
# 836  Mnemonic 1: p+enchant- something that enchants...
# 837  Mnemonic 1: Ghochu\nMnemonic 2: gauchy sounds ...
# 838  Mnemonic 1: You can think of it as the opposit...
# 839  Mnemonic 1: Affront=A(Aao)+front means if u co...
#
#                                              image_url     Set
# 0                                                  NaN   Set 1
# 1                                                  NaN   Set 1
# 2                                                  NaN   Set 1
# 3                                                  NaN   Set 1
# 4                                                  NaN   Set 1
# ..                                                 ...     ...
# 835                                                 []  Set 28
# 836  [https://dailyvocab.com/wp-content/uploads/201...  Set 28
# 837                                                 []  Set 28
# 838                                                 []  Set 28
# 839  [https://dailyvocab.com/wp-content/uploads/202...  Set 28
#
# [840 rows x 6 columns]

# %%
ankified['image_url'] = ankified['image_url'].apply(lambda x: x.strip('[]\'') if isinstance(x, str) else x) # Removing '[', ']', ''' (comma) from omage_url
ankified['image_url'] = ankified['image_url'].apply(lambda x: None if isinstance(x, list) and len(x)==0 else x ) # Removing empty lists from url
ankified['image_url'] = ankified['image_url'].apply(lambda x: x[0] if isinstance(x, list) else x ) # list to string
ankified['image_url'] = ankified['image_url'].apply(lambda x: '<img src="{}">'.format(x) if isinstance(x, str) else None)

# %%
ankified['image_url'].value_counts()
# Out:
# <img src="https://dailyvocab.com/wp-content/uploads/2020/03/Prolix.gif">                    1
# <img src="<img src="https://dailyvocab.com/wp-content/uploads/2013/10/diffidence.jpg">">    1
# <img src="https://dailyvocab.com/wp-content/uploads/2014/02/impudent.jpg">                  1
# <img src="https://dailyvocab.com/wp-content/uploads/2013/11/petulant.jpg">                  1
# <img src="https://dailyvocab.com/wp-content/uploads/2020/03/pretentious.gif">               1
#                                                                                            ..
# <img src="https://dailyvocab.com/wp-content/uploads/2019/07/Nascent.jpg">                   1
# <img src="<img src="https://dailyvocab.com/wp-content/uploads/2019/11/Frivolous.gif">">     1
# <img src="https://dailyvocab.com/wp-content/uploads/2020/03/philistine.gif">                1
# <img src="https://dailyvocab.com/wp-content/uploads/2015/05/Abject.jpg">                    1
# <img src="<img src="https://dailyvocab.com/wp-content/uploads/2013/08/venerate-1.png">">    1
# Name: image_url, Length: 257, dtype: int64

# %%
ankified.to_csv('anki_mnemonics.csv', index = None)

# %% [markdown]
# # Requests and BS4

# %%
page = requests.get(url)
page.status_code
# Out:
# 200

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(page.text, 'html.parser')

print(soup.prettify())

soup.find_all('p')

soup.find_all('p')[2].get_text()

# %% [markdown]
# ## Testing Section

# %%
word = 'abjure'

# %%
url = 'https://mnemonicdictionary.com/?word='+ word

page = requests.get(url)
tree = html.fromstring(page.content)
definition = tree.xpath('//li[@class="media list-group-item p-4"]/div[1]//text()')[12].strip()

# %%
tree.xpath('//li[@class="media list-group-item p-4"]/div/div//text()')[10]
# Out:
# ' (verb) formally reject or disavow a formerly held belief, usually under pressure\n                              '

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(page.text, 'html.parser')

print(soup.prettify())

# %%
soup.find_all('p')

soup.find_all('p')[2].get_text()
